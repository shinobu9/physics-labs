# %%
import pandas as pd
import numpy as np

data = pd.read_excel("f1.xlsx")
print(data.to_latex())

# %%
import matplotlib.pyplot as plt
plt.scatter(t, p)
#plt.scatter([0],[0], color='red')

z = np.polyfit(t, p, 1)
poly = np.poly1d(z)
plt.plot(t,poly(t),"r--")

plt.xlabel('T, K')
plt.ylabel('P, Па')
plt.show()
